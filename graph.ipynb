# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(80, 20), dpi=80)

a = [1.3953291406940274, 1.4892076798817788, 1.100465612965392, 1.5620148386710095, 0.9704102935975527, 0.7843515970190342, 0.8602824444201698, 0.5554565950380557, 0.8798484125993156, 0.7645831018494826]
b = [1.3917604586536854, 1.370622024644197, 1.026490990467484, 1.39688622264058, 0.8744780093122486, 0.6954866376363178, 0.8758825158417558, 0.5205863947668457, 1.009452987475873, 1.0654439636740385]

x = ['Biology','Chemistry', 'Computer Science', 'Physics', 'Engineering', 'Economics', 'Psychology', 'Sociology', 'Philosophy', 'Art']


fig, axs = plt.subplots(2, figsize=(15,15))
fig.suptitle('The KLD between news and displines at lexical level')
axs[0].bar(range(len(x)),a,tick_label=x, color="gray")
axs[1].bar(range(len(x)),b,tick_label=x, color="brown")
axs[0].title.set_text('News VS Discplines')
axs[1].title.set_text('Discplines VS News')

plt.savefig('lemma_compare.png')

# %%
from wordcloud import WordCloud

# %%
with open('sociology-tokens.txt') as f:
    tokens = f.read().lower().splitlines()

# %%
text = ' '.join([str(item) for item in tokens])

# %%
len(text)
# Out:
# 188260360

# %%
text = text[:30000000]

# %%
import matplotlib.pyplot as plt

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('sociology_wordcloud.png')

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(80, 20), dpi=80)

a = [0.33694534541039367, 0.32693384932272416, 0.3095908250749959, 0.40949426034225844, 0.2207089868032602, 0.2820654918433485, 0.2575180974280906, 0.22213570469393673, 0.2700327413215362, 0.1887348437496943]
b = [0.2668384731881055, 0.2749958425719585, 0.22246637317128926, 0.40949426034225844, 0.20859149337660554, 0.19154114869734862, 0.18398224835268717, 0.14965210674826857, 0.19412978207494636, 0.1268013546433302 ]

x = ['Biology','Chemistry', 'Computer Science', 'Physics', 'Engineering', 'Economics', 'Psychology', 'Sociology', 'Philosophy', 'Art']


fig, axs = plt.subplots(2, figsize=(15,15))
fig.suptitle('The KLD between news and displines at grammatical level')
axs[0].bar(range(len(x)),a,tick_label=x, color="gray")
axs[1].bar(range(len(x)),b,tick_label=x, color="brown")
axs[0].title.set_text('News VS Discplines')
axs[1].title.set_text('Discplines VS News')

plt.savefig('pos_compare.png')

# %%
sum([0.7843515970190342, 0.5554565950380557, 0.8798484125993156, 0.7645831018494826])/4
# Out:
# 0.746059926626472

# %%
sum([1.5620148386710095, 0.9704102935975527])/2
# Out:
# 1.2662125661342811

# %%
sum([1.39688622264058, 0.8744780093122486])/2
# Out:
# 1.1356821159764143

# %%
sum([0.6954866376363178, 0.5205863947668457, 1.009452987475873, 1.0654439636740385])/4
# Out:
# 0.8227424958882688

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(80, 20), dpi=80)

a = [0.746059926626472, 0.8602824444201698, 1.3953291406940274, 1.4892076798817788, 1.2662125661342811, 1.100465612965392]
b = [0.8227424958882688, 0.8758825158417558, 1.3917604586536854, 1.370622024644197, 1.1356821159764143, 1.026490990467484 ]

x = ['Soc&Hum ','Psychology', 'Biology', 'Chemistry', 'Phy&Eng', 'Computer']

fig, axs = plt.subplots(2, figsize=(15,15))
fig.suptitle('The KLD between news and domains at grammatical level')
axs[0].bar(range(len(x)),a,tick_label=x, color="blue")
axs[1].bar(range(len(x)),b,tick_label=x, color="green")
axs[0].title.set_text('News VS Domains')
axs[1].title.set_text('Domains VS News')

plt.savefig('domain_lemma_compare.png')

# %%
sum([0.2820654918433485, 0.22213570469393673, 0.2700327413215362, 0.1887348437496943])/4
# Out:
# 0.24074219540212893

# %%
sum([0.40949426034225844, 0.2207089868032602])/2
# Out:
# 0.31510162357275934

# %%
sum([0.19154114869734862,0.14965210674826857, 0.19412978207494636, 0.1268013546433302])/4
# Out:
# 0.16553109804097343

# %%
sum([0.40949426034225844, 0.20859149337660554])/2
# Out:
# 0.309042876859432

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(80, 20), dpi=80)

a = [0.24074219540212893, 0.2575180974280906, 0.2668384731881055, 0.2749958425719585,0.31510162357275934, 0.22246637317128926]
b = [0.16553109804097343, 0.18398224835268717,  0.2668384731881055, 0.2749958425719585, 0.309042876859432, 0.22246637317128926]

x = ['Soc&Hum ','Psychology', 'Biology', 'Chemistry', 'Phy&Eng', 'Computer']

fig, axs = plt.subplots(2, figsize=(15,15))
fig.suptitle('The KLD between news and domains at grammatical level ')
axs[0].bar(range(len(x)),a,tick_label=x, color="red")
axs[1].bar(range(len(x)),b,tick_label=x, color="dark yellow")
axs[0].title.set_text('News VS Domains')
axs[1].title.set_text('Domains VS News')

plt.savefig('domain_gramma_compare.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-40814d1bdee3> in <module>
#      14 fig.suptitle('The KLD between news and domains at grammatical level ')
#      15 axs[0].bar(range(len(x)),a,tick_label=x, color="red")
# ---> 16 axs[1].bar(range(len(x)),b,tick_label=x, color="dark yellow")
#      17 axs[0].title.set_text('News VS Domains')
#      18 axs[1].title.set_text('Domains VS News')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
# ...
